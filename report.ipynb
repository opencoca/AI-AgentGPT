# %% [markdown]
# <a href="https://colab.research.google.com/github/opencoca/AI-AgentGPT/blob/main/report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install altair vega_datasets mercury pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 23.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 92.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.0/422.0 kB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 69.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.6/256.6 kB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 45.6 MB/s eta 0:00:00
# ...

# %%
import altair as alt
from vega_datasets import data
import mercury as mr

# %%
app = mr.App(title="Car report 📊", description="Report based on cars dataset")
# Out:
# mercury.App

# %%
cars = data.cars()

# %%
origin = mr.MultiSelect(label="Select origin", value=cars.Origin.unique(), choices=cars.Origin.unique())
# Out:
# mercury.MultiSelect

# %%
df = cars[cars.Origin.isin(origin.value)]

# %%
show_bars = mr.Checkbox(label="Show bars plot", value=True)
# Out:
# mercury.Checkbox

# %%
mr.NumberBox([
    mr.NumberBox(data=df.shape[0], title="Total cars"),
    mr.NumberBox(data=df.Horsepower.max(), title="Max Horse Power"),
    mr.NumberBox(data=df.Miles_per_Gallon.max(), title="Max MPG"),
])
# Out:
# <style scoped>
#         .numberbox-container {
#         width: 100%;
#         display: flex;
#         flex-direction: row;
#         }
#         @media (max-width: 800px) {
#         .numberbox-container {
#             flex-direction: column;
#         }
#         }
#         </style><div class="numberbox-container" style="display: flex; background: #fff;">
# <div style="text-align: center; width: 100%; border: 1px solid lightgray; margin-right: 15px; margin-top: 15px; padding-top: 40px; padding-bottom: 30px; background: white; border-radius:5px">
#   <span style="font-size: 4em; color: black; font-family: monospace; ">406</span>
#
#   <span style="font-size: 2em; color: gray; display: block; padding-top: 20px; font-family: monospace; line-height: 1.3em;">Total cars</span>
# </div>
#
# <div style="text-align: center; width: 100%; border: 1px solid lightgray; margin-right: 15px; margin-top: 15px; padding-top: 40px; padding-bottom: 30px; background: white; border-radius:5px">
# ...

# %%
points = alt.Chart(df).mark_point().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    color='Origin:N',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive().properties(
    width="container"
)

bars = alt.Chart(df).mark_bar().encode(
    x='count()',
    y='Origin:N',
    color='Origin:N'
).properties(
    width="container"
)

charts = [points]
if show_bars.value:
    charts += [bars]

alt.vconcat(
    *charts
).configure(autosize="fit-x")
# Out:
# alt.VConcatChart(...)

# %%
df.head(20)
# Out:
#                                 Name  Miles_per_Gallon  Cylinders  \
# 0          chevrolet chevelle malibu              18.0          8
# 1                  buick skylark 320              15.0          8
# 2                 plymouth satellite              18.0          8
# 3                      amc rebel sst              16.0          8
# 4                        ford torino              17.0          8
# 5                   ford galaxie 500              15.0          8
# 6                   chevrolet impala              14.0          8
# 7                  plymouth fury iii              14.0          8
# 8                   pontiac catalina              14.0          8
# 9                 amc ambassador dpl              15.0          8
# 10              citroen ds-21 pallas               NaN          4
# 11  chevrolet chevelle concours (sw)               NaN          8
# 12                  ford torino (sw)               NaN          8
# ...
